# %%
# %matplotlib inline
import numpy as np
import pandas as pd
"""Pandas is a python library that makes handling tabular data easier.
'Data Frames' and 'Series' ~ that allow to slice and slice rows and columns of information.
Pandas provides in-memory 2d table object called dataframe.
Pandas head() method is used to return top n (5 by default) rows of data frame or series.
"""
df = pd.read_csv("data.csv")
df.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
"""head() is a handy way to visualize what is loaded. We can pass it an integer
to see some specific number of rows at the beginning of DataFrame"""
df.head(10)
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
# 5    785275        FL  CLAY COUNTY            0.0      515035.62
# 6    995932        FL  CLAY COUNTY            0.0    19260000.00
# 7    223488        FL  CLAY COUNTY       328500.0      328500.00
# 8    433512        FL  CLAY COUNTY       315000.0      315000.00
# 9    142071        FL  CLAY COUNTY       705600.0      705600.00
#
#    fl_site_limit  fr_site_limit     tiv_2011     tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0    498960.00    792148.90                 0.0
# 1      1322376.3      1322376.3   1322376.30   1438163.57                 0.0
# ...

# %%
df.tail(4) # to view end of data
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 36630    465875        FL  PINELLAS COUNTY      1297057.5      1297057.5
# 36631    791209        FL  PINELLAS COUNTY       173286.9       173286.9
# 36632    322627        FL  PINELLAS COUNTY      1499781.6      1499781.6
# 36633    398149        FL  PINELLAS COUNTY       373488.3       373488.3
#
#        fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  \
# 36630      1297057.5      1297057.5  1297057.5  1577500.79
# 36631            0.0            0.0   173286.9   205527.97
# 36632            0.0            0.0  1499781.6  1768782.43
# 36633            0.0            0.0   373488.3   596003.67
#
#        eq_site_deductible  hu_site_deductible  fl_site_deductible  \
# 36630                 0.0                 0.0                 0.0
# 36631                 0.0                 0.0                 0.0
# 36632                 0.0                 0.0                 0.0
# ...

# %%
df.shape # to know about dimensions
# Out:
# (36634, 18)

# %%
df.size # The total size of the data frame is the rows * columns.
# Out:
# 659412

# %%
len(df) # len() function gives no. of rows in a DataFrame.
# Out:
# 36634

# %%
df.columns # if DataFrame has named columns(extracted automatically from the first row of a .csv file), it will give an array of them back.
# Out:
# Index(['policyID', 'statecode', 'county', 'eq_site_limit', 'hu_site_limit',
#        'fl_site_limit', 'fr_site_limit', 'tiv_2011', 'tiv_2012',
#        'eq_site_deductible', 'hu_site_deductible', 'fl_site_deductible',
#        'fr_site_deductible', 'point_latitude', 'point_longitude', 'line',
#        'construction', 'point_granularity'],
#       dtype='object')

# %%
"""Extracting a single column from DataFrame, it gives bacl a "Series" in Pandas."""
df['line']
# Out:
# 0        Residential
# 1        Residential
# 2        Residential
# 3        Residential
# 4        Residential
# 5        Residential
# 6         Commercial
# 7        Residential
# 8        Residential
# 9        Residential
# 10       Residential
# 11       Residential
# 12       Residential
# 13       Residential
# 14       Residential
# 15       Residential
# 16       Residential
# 17       Residential
# 18       Residential
# 19       Residential
# 20       Residential
# 21        Commercial
# 22       Residential
# 23       Residential
# 24       Residential
# 25       Residential
# 26       Residential
# 27       Residential
# 28       Residential
# 29       Residential
#             ...
# 36604    Residential
# 36605    Residential
# 36606    Residential
# 36607    Residential
# 36608    Residential
# 36609     Commercial
# 36610    Residential
# 36611    Residential
# 36612    Residential
# 36613    Residential
# 36614    Residential
# 36615    Residential
# ...

# %%
"""To extract a given range of rows from a named column"""
df['line'][:20]
# Out:
# 0     Residential
# 1     Residential
# 2     Residential
# 3     Residential
# 4     Residential
# 5     Residential
# 6      Commercial
# 7     Residential
# 8     Residential
# 9     Residential
# 10    Residential
# 11    Residential
# 12    Residential
# 13    Residential
# 14    Residential
# 15    Residential
# 16    Residential
# 17    Residential
# 18    Residential
# 19    Residential
# Name: line, dtype: object

# %%
# To extract a single value from a specified column/ row combination.
df['line'] [6]
# Out:
# 'Commercial'

# %%
# To extract more than one column
df[['policyID', 'line']]
# Out:
#        policyID         line
# 0        119736  Residential
# 1        448094  Residential
# 2        206893  Residential
# 3        333743  Residential
# 4        172534  Residential
# 5        785275  Residential
# 6        995932   Commercial
# 7        223488  Residential
# 8        433512  Residential
# 9        142071  Residential
# 10       253816  Residential
# 11       894922  Residential
# 12       422834  Residential
# 13       582721  Residential
# 14       842700  Residential
# 15       874333  Residential
# 16       580146  Residential
# 17       456149  Residential
# 18       767862  Residential
# 19       353022  Residential
# 20       367814  Residential
# 21       671392   Commercial
# 22       772887  Residential
# 23       983122  Residential
# 24       934215  Residential
# 25       385951  Residential
# 26       716332  Residential
# 27       751262  Residential
# 28       633663  Residential
# 29       105851  Residential
# ...         ...          ...
# ...

# %%
# To extract specific ranges of rows from more than one column.
df[['policyID', 'line']][:10]
# Out:
#    policyID         line
# 0    119736  Residential
# 1    448094  Residential
# 2    206893  Residential
# 3    333743  Residential
# 4    172534  Residential
# 5    785275  Residential
# 6    995932   Commercial
# 7    223488  Residential
# 8    433512  Residential
# 9    142071  Residential

# %%
# Sorting DataFrames by a specific column.
df.sort_values(['point_granularity'])
# Out:
#        policyID statecode               county  eq_site_limit  hu_site_limit  \
# 0        119736        FL          CLAY COUNTY       498960.0      498960.00
# 22211    335649        FL       BROWARD COUNTY            0.0        2447.14
# 22210    351885        FL       BROWARD COUNTY            0.0      148011.25
# 22209    985506        FL       BROWARD COUNTY            0.0      116347.06
# 22208    619251        FL       BROWARD COUNTY            0.0       29602.25
# 22207    912295        FL       BROWARD COUNTY            0.0       19109.45
# 22206    617661        FL       BROWARD COUNTY            0.0       19109.45
# 22205    876884        FL       BROWARD COUNTY            0.0      389095.43
# 22204    229549        FL       BROWARD COUNTY            0.0       10397.63
# 22203    249802        FL       BROWARD COUNTY       542805.3      542805.30
# 22202    746516        FL       BROWARD COUNTY       644350.5      644350.50
# ...

# %%
"""To break down the number of unique values in a given column into
Series using value_counts(): distribution of data."""
counts = df['line'].value_counts()
counts
# Out:
# Residential    30838
# Commercial      5796
# Name: line, dtype: int64

# %%
counts.plot(kind='bar')

# %%
df.new = df[['county','line']][5:10]
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
dist = df.new['county'].value_counts()

# %%
dist.plot(kind='hist')

# %%
df[['policyID', 'line']][:,5:10]
